# %% [markdown]
# ## In this notebook, we will work with some the data location provider Forosquare.

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
